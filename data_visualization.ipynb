# %% [markdown]
# ## First Load in the Data Set from Kaggle

# %%
# if dataset folder doesn't exist, download the dataset from kaggle
import os
import zipfile
if not os.path.exists("dataset"):
    # %pip install kaggle
    # also need to get kaggle api key and put it in ~/.kaggle/kaggle.json
    # !kaggle datasets download -d jehanbhathena/weather-dataset

    with zipfile.ZipFile("weather-dataset.zip", 'r') as zip_ref:
        zip_ref.extractall()
# Out:
# Requirement already satisfied: kaggle in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (1.6.4)
# Requirement already satisfied: six>=1.10 in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (8.0.3)
# Requirement already satisfied: urllib3 in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (2.2.0)
# Requirement already satisfied: bleach in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from requests->kaggle) (3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: colorama in c:\users\mikek\desktop\dukeaipi\aipi590cv\aipi590_cv_proj1\.venv\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.3.2
# [notice] To update, run: c:\Users\MikeK\Desktop\DukeAIPI\AIPI590CV\AIPI590_CV_Proj1\.venv\Scripts\python.exe -m pip install --upgrade pip
# weather-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)

# %% [markdown]
# ## Load in Images

# %%
# for each folder in dataset, display the number of files in it and show the first image
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

for folder in os.listdir("dataset"):
    print(folder, len(os.listdir("dataset/"+folder)))
    img = mpimg.imread("dataset/"+folder+"/"+random.choice(os.listdir("dataset/"+folder)))
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# dew 698
# fogsmog 851
# frost 475
# glaze 639
# hail 591
# lightning 377
# rain 526
# rainbow 232
# rime 1160
# sandstorm 692
# snow 621
