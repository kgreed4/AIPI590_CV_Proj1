# %% [markdown]
# ## First Load in the Data Set from Kaggle

# %%
# if dataset folder doesn't exist, download the dataset from kaggle
import os
import zipfile
if not os.path.exists("dataset"):
    # %pip install kaggle
    # also need to get kaggle api key and put it in ~/.kaggle/kaggle.json
    # !kaggle datasets download -d jehanbhathena/weather-dataset

    with zipfile.ZipFile("weather-dataset.zip", 'r') as zip_ref:
        zip_ref.extractall()
# Out:
# Requirement already satisfied: kaggle in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (1.6.4)
# Requirement already satisfied: six>=1.10 in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (2023.11.17)
# Requirement already satisfied: python-dateutil in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (4.66.1)
# Requirement already satisfied: python-slugify in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (8.0.3)
# Requirement already satisfied: urllib3 in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (2.0.4)
# Requirement already satisfied: bleach in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from kaggle) (6.0.0)
# Requirement already satisfied: webencodings in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from requests->kaggle) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/katiegreed/anaconda3/envs/AIPI510/lib/python3.11/site-packages (from requests->kaggle) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/katiegreed/.kaggle/kaggle.json'
# Downloading weather-dataset.zip to /Users/katiegreed/Documents/Duke AI Masters/AIPI 590 - Computer Vision/Project01/AIPI590_CV_Proj1
# 100%|████████████████████████████████████████| 587M/587M [00:29<00:00, 28.3MB/s]
# 100%|████████████████████████████████████████| 587M/587M [00:29<00:00, 20.7MB/s]

# %% [markdown]
# ## Load in Images

# %%
# for each folder in dataset, display the number of files in it and show the first image
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random

for folder in os.listdir("dataset"):
    print(folder, len(os.listdir("dataset/"+folder)))
    img = mpimg.imread("dataset/"+folder+"/"+random.choice(os.listdir("dataset/"+folder)))
    imgplot = plt.imshow(img)
    plt.show()
# Out:
# lightning 377
# sandstorm 692
# glaze 639
# rain 526
# rime 1160
# frost 475
# fogsmog 851
# hail 591
# dew 698
# rainbow 232
# snow 621

# %% [markdown]
# ## Create CSV with image paths as features and their weather as label

# %%
import csv

# Set the path to your dataset directory
dataset_directory = 'dataset'

# Specify the CSV file name
csv_file_name = 'images_labeled.csv'

# Open the CSV file for writing
with open(csv_file_name, mode='w', newline='') as file:
    writer = csv.writer(file)
    # Write the header row
    writer.writerow(['filepath', 'label'])
    
    # Walk through the dataset directory
    for root, dirs, files in os.walk(dataset_directory):
        for file in files:
            # Check if the file is an image (e.g., .jpg, .png)
            if file.lower().endswith(('.png', '.jpg', '.jpeg')):
                # Extract the label from the folder name
                label = os.path.basename(root)
                # Construct the file path
                file_path = os.path.join(root, file)
                # Write the file path and label to the CSV
                writer.writerow([file_path, label])

print(f'CSV file {csv_file_name} has been created successfully.')
# Out:
# CSV file images_labeled.csv has been created successfully.

# %% [markdown]
# ## Create train, test, val folders

# %%
# Divide the data into training, test, and validation sets
import pandas as pd
from sklearn.model_selection import train_test_split

# Load the data from the CSV file
data = pd.read_csv(csv_file_name)

# Split the data into 70% training, 15% validation, and 15% test sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=0)
valid_data, test_data = train_test_split(test_data, test_size=0.5, random_state=0)

# Save the data to new CSV
split_data_file_name = 'images_labeled_split.csv'
train_data.to_csv('train_'+split_data_file_name, index=False)
valid_data.to_csv('valid_'+split_data_file_name, index=False)
test_data.to_csv('test_'+split_data_file_name, index=False)
